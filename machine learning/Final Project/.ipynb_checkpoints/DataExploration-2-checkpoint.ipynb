# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the data

# %%
#load the full csv
#full = pd.read_csv('C:/Users/jchun/OneDrive/Documents/425/fulldata.csv')
full = pd.read_csv('fulldata.csv')

# %%
del full['Unnamed: 0']   #delete"Unnamed: 0"
del full['onlinedating.1']  #delete"onlinedating.1"

# %%
full.head() #show the data after cleaning
# Out:
#    Year       State  Fiscal.Policy  Regulatory.Policy  Personal.Freedom  \
# 0  2004     Alabama       0.083858           0.097501         -0.155371
# 1  2004      Alaska      -0.205665           0.076301          0.050388
# 2  2004     Arizona      -0.008760           0.188783         -0.036909
# 3  2004    Arkansas      -0.030705           0.102758         -0.075841
# 4  2004  California      -0.117287          -0.287566          0.006635
#
#    Economic.Freedom  Overall.Freedom  unemployment  beer  wine  ...  chink  \
# 0          0.181359         0.025988           5.7  1.19  0.20  ...   0.00
# 1         -0.129364        -0.078977           7.5  1.31  0.44  ...   0.00
# 2          0.180022         0.143113           5.0  1.40  0.34  ...   0.00
# 3          0.072053        -0.003789           5.7  1.04  0.15  ...   0.00
# 4         -0.404854        -0.398219           6.2  1.07  0.52  ...   2.75
#
#       racism     nigger  goodbooks  onlineclass  eventsnearme      jokes  \
# 0   8.000000  18.500000   3.833333     3.166667           0.0  47.750000
# 1   8.500000  14.583333   7.000000    13.916667           0.0  53.583333
# 2   4.916667  12.416667   4.416667     5.750000           0.0  40.166667
# 3  10.416667  17.583333  17.416667    15.250000           0.0  56.083333
# 4  19.833333  11.250000   7.750000     5.750000           0.0  29.166667
#
#     football   religion  wheretovote
# 0  13.833333  36.666667     4.333333
# 1   4.083333  35.083333     3.583333
# 2   6.250000  36.750000     6.833333
# 3   8.916667  39.000000     5.166667
# 4   5.000000  32.333333     0.000000
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Removing columns that have values of 0

# %%
#delete all the variables with 0 in order to get the data with meaning
for col in full.columns:
    if(0 in full[col].values):
        del full[col]

# %%
#add the recession feature("rec"), since there is a delay when the job market react to the recession, we let the recession feature in 2008 to 2011 equals to 1  
#full['rec']
full['rec'] = full.apply(lambda row: 1 if row['Year'] in [2008,2009,2010,2011] else 0,axis=1)
#full['rec'] = full.apply(lambda row: 1 if row['Year'] > 2007 else 0,axis=1)

# %%
#After removing the variables with 0, there are 23 variables left. They are shown in the following. 1th variable: Year; 
#2rd: State; 3th: Fiscal Policy ; 4th: Regulatory Policy; 5th: Personal Freedom to do jobs; 6th:Economic Freedom to do choice
#7th: Overall freedom; 8th: unemployment rate; 9th: beer sale; 10th: wine sale; 11th: how many times people go to church; 
#12th: 64 bit operating system; 13th: how to measure whether pregnant or not; 14th: jobsin network webite for searching jobs
#15th: anxiety; 16th: onlinedating apps; 17th: racism; 18th: racism words; 19th: online class; 20th:jokes; 21th: football game
#22th: religion; 23th:recession background
full.columns
# Out:
# Index(['Year', 'State', 'Fiscal.Policy', 'Regulatory.Policy',
#        'Personal.Freedom', 'Economic.Freedom', 'Overall.Freedom',
#        'unemployment', 'beer', 'wine', 'church', '64bit', 'pregnancy',
#        'jobsin', 'anxiety', 'onlinedating', 'racism', 'nigger', 'onlineclass',
#        'jokes', 'football', 'religion', 'rec'],
#       dtype='object')

# %%
#to see the relationship between features and ground truth label(unemployment rate), we plot a correlation plot. From the result, we can see that 64bit, jobsin and rec are positively related to the unemployment rate.
from matplotlib import pyplot

dims = (20, 20)
fig, ax = pyplot.subplots(figsize=dims)

#cols = [c for c in df.columns if (c.lower()[:8] != 'country_' or \
#        c == 'country_US') and 'os' not in c and 'screen' not in c and 'browser' not in c]
cols = [c for c in full.columns if (c.lower()[:8] != 'country_')]
dfCorr=full[cols]

corr = dfCorr.corr()
#Pastel1 terrain
sns.heatmap(ax=ax,data=corr,cmap="terrain")

# %%
# We visualized our ground truth label, unemployment rate. 
plt.hist(x=full['unemployment'], bins='auto', color='#0504aa',alpha=0.7, rwidth=0.85)
# Out:
# (array([ 32.,  49.,  66., 102.,  77.,  72.,  63.,  43.,  42.,  25.,  24.,
#          12.,  25.,  10.,   3.,   1.,   2.,   2.]),
#  array([ 2.6       ,  3.21666667,  3.83333333,  4.45      ,  5.06666667,
#          5.68333333,  6.3       ,  6.91666667,  7.53333333,  8.15      ,
#          8.76666667,  9.38333333, 10.        , 10.61666667, 11.23333333,
#         11.85      , 12.46666667, 13.08333333, 13.7       ]),
#  <a list of 18 Patch objects>)

# %%
#We classified the unemployment rate into 0(unemployment rate smaller than 7) and 1(unemployment rate bigger than 7)
full['highunem'] = full.apply(lambda row: 1 if row['unemployment'] > 7 else 0, axis=1)

# %%
full.head()
# Out:
#    Year       State  Fiscal.Policy  Regulatory.Policy  Personal.Freedom  \
# 0  2004     Alabama       0.083858           0.097501         -0.155371
# 1  2004      Alaska      -0.205665           0.076301          0.050388
# 2  2004     Arizona      -0.008760           0.188783         -0.036909
# 3  2004    Arkansas      -0.030705           0.102758         -0.075841
# 4  2004  California      -0.117287          -0.287566          0.006635
#
#    Economic.Freedom  Overall.Freedom  unemployment  beer  wine  ...  \
# 0          0.181359         0.025988           5.7  1.19  0.20  ...
# 1         -0.129364        -0.078977           7.5  1.31  0.44  ...
# 2          0.180022         0.143113           5.0  1.40  0.34  ...
# 3          0.072053        -0.003789           5.7  1.04  0.15  ...
# 4         -0.404854        -0.398219           6.2  1.07  0.52  ...
#
#      anxiety  onlinedating     racism     nigger  onlineclass      jokes  \
# 0  19.416667     10.750000   8.000000  18.500000     3.166667  47.750000
# 1  20.916667     10.750000   8.500000  14.583333    13.916667  53.583333
# 2  20.250000     10.250000   4.916667  12.416667     5.750000  40.166667
# 3  27.333333     10.666667  10.416667  17.583333    15.250000  56.083333
# 4  20.250000      7.750000  19.833333  11.250000     5.750000  29.166667
#
#     football   religion  rec  highunem
# 0  13.833333  36.666667    0         0
# 1   4.083333  35.083333    0         1
# 2   6.250000  36.750000    0         0
# 3   8.916667  39.000000    0         0
# 4   5.000000  32.333333    0         0
#
# [5 rows x 24 columns]

# %%
#divide the full sample into training data and testing data
from random import shuffle
n = len(full) #number of rows in your dataset
indices = list(range(n))
shuffle(indices)

df = full.loc[indices[:400]]
dfTest = full.loc[indices[400:]]

# %%
df.columns
# Out:
# Index(['Year', 'State', 'Fiscal.Policy', 'Regulatory.Policy',
#        'Personal.Freedom', 'Economic.Freedom', 'Overall.Freedom',
#        'unemployment', 'beer', 'wine', 'church', '64bit', 'pregnancy',
#        'jobsin', 'anxiety', 'onlinedating', 'racism', 'nigger', 'onlineclass',
#        'jokes', 'football', 'religion', 'rec', 'highunem'],
#       dtype='object')

# %%
#we will use these variables in our model
indFeats = [
            'beer','wine',
    '64bit','pregnancy','jobsin','anxiety','onlinedating','racism','nigger',
    'onlineclass','jokes','football','religion','church','rec']
    #'Fiscal.Policy','Regulatory.Policy','Personal.Freedom','Economic.Freedom','Overall.Freedom']

# %%
#normalize the features before regressing them because our label are in (0,1) form
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Create a features DF
from sklearn.preprocessing import normalize

dfX = df[indFeats]
df_test_X = dfTest[indFeats]
dfX = normalize(dfX, axis=0, norm='max')
df_test_X = normalize(df_test_X, axis=0, norm='max')

# Create a label DF
dfY = df['unemployment']
df_test_Y = dfTest['unemployment']

# %% [markdown]
# ## Linear Regression Model

# %%
lm = linear_model.LinearRegression()
lm.fit(dfX, dfY)

dfPred = lm.predict(df_test_X)

# %%
import statsmodels.api as sm

model = sm.OLS(dfY,dfX)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           unemployment   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     465.5
# Date:                Wed, 06 Mar 2019   Prob (F-statistic):          5.20e-236
# Time:                        12:01:37   Log-Likelihood:                -722.42
# No. Observations:                 400   AIC:                             1475.
# Df Residuals:                     385   BIC:                             1535.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -2.3877      0.692     -3.450      0.001      -3.749      -1.027
# x2             3.4653      0.656      5.286      0.000       2.176       4.754
# x3             4.1342      0.728      5.678      0.000       2.702       5.566
# x4             1.6581      0.924      1.794      0.074      -0.159       3.476
# x5             3.1798      0.895      3.552      0.000       1.420       4.940
# x6             0.0172      0.735      0.023      0.981      -1.427       1.462
# x7            -0.9480      0.623     -1.523      0.129      -2.172       0.276
# x8            -0.5429      0.443     -1.226      0.221      -1.414       0.328
# x9             1.8653      0.638      2.921      0.004       0.610       3.121
# x10           -0.5171      0.673     -0.768      0.443      -1.841       0.807
# x11           -1.4455      1.021     -1.416      0.158      -3.453       0.562
# x12           -1.8608      0.921     -2.020      0.044      -3.672      -0.049
# x13            3.7347      1.029      3.628      0.000       1.711       5.759
# x14            2.1872      0.689      3.175      0.002       0.833       3.541
# x15            0.8411      0.243      3.466      0.001       0.364       1.318
# ==============================================================================
# Omnibus:                       15.372   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.527
# Skew:                           0.318   Prob(JB):                     2.12e-05
# Kurtosis:                       3.942   Cond. No.                         32.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(indFeats)
# The coefficients
print('Coefficients: ', lm.coef_)
print('Intercept: ', lm.intercept_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(np.array(df_test_Y),dfPred))
print("Mean absolute error: %.2f" % mean_absolute_error(np.array(df_test_Y),dfPred))
# Out:
# ['beer', 'wine', '64bit', 'pregnancy', 'jobsin', 'anxiety', 'onlinedating', 'racism', 'nigger', 'onlineclass', 'jokes', 'football', 'religion', 'church', 'rec']
# Coefficients:  [-4.5388908   1.53349048  3.54799321 -2.51566032  4.05235637 -2.67527894
#  -1.96013412 -0.87382483  1.54552617 -0.47320176 -0.24802909 -1.27714332
#   0.0999336   0.78823211  0.67071966]
# Intercept:  8.675301743308905
# Mean squared error: 2.19
# Mean absolute error: 1.16

# %% [markdown]
# After getting the regression results, we calculate the MSE and MAE of testing samples for our first model so that we can compare the accuracy of the  model with other models.

# %%
import matplotlib.pyplot as plt

dims = (10, 10)
fig, ax = pyplot.subplots(figsize=dims)
plt.title('Coefficients for all Features')
g = sns.barplot(ax=ax, x=indFeats, y=lm.coef_).set_xticklabels(rotation=90,labels=indFeats)

# %% [markdown]
# ## Random Forest

# %%
df.head()
# Out:
#      Year         State  Fiscal.Policy  Regulatory.Policy  Personal.Freedom  \
# 207  2008      Delaware      -0.067215           0.028387         -0.058794
# 30   2004    New Mexico      -0.412846           0.032180          0.106018
# 116  2006      Kentucky      -0.046128           0.091818         -0.135912
# 638  2016  Rhode Island       0.060011          -0.189248          0.041829
# 437  2012  Pennsylvania       0.194755          -0.174699          0.003475
#
#      Economic.Freedom  Overall.Freedom  unemployment  beer  wine  ...  \
# 207         -0.038828        -0.097621           4.9  1.35  0.57  ...
# 30          -0.380666        -0.274648           5.5  1.46  0.25  ...
# 116          0.045690        -0.090223           5.7  1.04  0.17  ...
# 638         -0.129237        -0.087408           5.2  0.94  0.58  ...
# 437          0.020056         0.023530           7.8  1.36  0.31  ...
#
#        anxiety  onlinedating     racism     nigger  onlineclass      jokes  \
# 207  22.000000      6.166667  15.250000  18.083333     7.916667  20.166667
# 30   25.666667     17.083333   8.166667  21.083333     8.416667  45.333333
# 116  20.666667     33.833333  23.333333  18.333333     4.166667  51.750000
# 638  52.666667      4.000000   9.333333  11.666667     5.666667  13.916667
# 437  35.583333      7.416667   5.500000  17.250000     5.666667  23.166667
#
#       football   religion  rec  highunem
# 207   8.583333  30.500000    1         0
# 30    5.500000  41.250000    0         0
# 116   9.333333  34.500000    0         0
# 638   7.833333  24.750000    0         0
# 437  11.000000  29.916667    0         1
#
# [5 rows x 24 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score


dfBoolY = df['highunem']
dt = DecisionTreeClassifier(max_depth=6,max_leaf_nodes=12) #set the maximum number of the layer to 6
print(cross_val_score(dt, dfX, dfBoolY, cv=10))
mod = dt.fit(dfX,dfBoolY,)
# Out:
# [0.80487805 0.80487805 0.82926829 0.75       0.775      0.775
#  0.75       0.87179487 0.87179487 0.79487179]

# %%
#visualize the decision tree
from sklearn import tree
import graphviz

dot_data = tree.export_graphviz(mod, out_file=None, 
                         feature_names=indFeats,  
                         class_names='isgritty',  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=10,max_features=8,n_estimators=100)
rf.fit(dfX, dfY)

dims = (10, 10)
fig, ax = pyplot.subplots(figsize=dims)
plt.title('Coefficients for all Features Predicting Unemployment')
g = sns.barplot(ax=ax, x=indFeats, y=rf.feature_importances_).set_xticklabels(rotation=90,labels=indFeats)

print(indFeats)
print(rf.feature_importances_)
# Out:
# ['beer', 'wine', '64bit', 'pregnancy', 'jobsin', 'anxiety', 'onlinedating', 'racism', 'nigger', 'onlineclass', 'jokes', 'football', 'religion', 'church', 'rec']
# [0.08762588 0.03364754 0.27160438 0.04411043 0.04599668 0.06242568
#  0.10769385 0.03145081 0.04116275 0.0232326  0.03458116 0.03122394
#  0.0304224  0.03870681 0.11611508]

# %%
#Mean Square Error of the random forest model
dfPred = rf.predict(df_test_X)
print("Mean squared error: %.2f" % mean_squared_error(np.array(df_test_Y),dfPred))
print("Mean absolute error: %.2f" % mean_absolute_error(np.array(df_test_Y),dfPred))
# Out:
# Mean squared error: 1.69
# Mean absolute error: 1.00

# %% [markdown]
# ## Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
# define the model
def larger_model():
    # create model
    model = Sequential()
    model.add(Dense(20, input_dim=15, kernel_initializer='normal', activation='relu'))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
seed = 10
np.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=larger_model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, dfX, dfY, cv=kfold)
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Larger: -1.95 (0.49) MSE

# %%
model = larger_model()
model.fit(dfX, dfY, epochs=1000, verbose=0)

# %%
#Mean Square Error of the neural network model
dfPred = model.predict(df_test_X)
print("Mean squared error: %.2f" % mean_squared_error(np.array(df_test_Y),dfPred))
print("Mean absolute error: %.2f" % mean_absolute_error(np.array(df_test_Y),dfPred))
# Out:
# Mean squared error: 1.90
# Mean absolute error: 1.07
